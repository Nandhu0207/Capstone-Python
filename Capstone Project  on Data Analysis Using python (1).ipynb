# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
movie=pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")   
movie
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movie.shape
# Out:
# (4803, 20)

# %%
movie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
# # task 1

# %%
f50 = movie.head(50)
titles_and_genres = f50[['title', 'genres']]
print(titles_and_genres)
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# # task 2

# %%
movie.isnull().any()
# Out:
# budget                  False
# genres                  False
# homepage                 True
# id                      False
# keywords                False
# original_language       False
# original_title          False
# overview                 True
# popularity              False
# production_companies    False
# production_countries    False
# release_date             True
# revenue                 False
# runtime                  True
# spoken_languages        False
# status                  False
# tagline                  True
# title                   False
# vote_average            False
# vote_count              False
# dtype: bool

# %%
movie['homepage'].fillna('homepage',inplace=True)

# %%
movie['overview'].fillna('overview',inplace=True)

# %%
movie['release_date'].fillna('release_date',inplace=True)

# %%
movie['runtime'].fillna('runtime',inplace=True)

# %%
movie['tagline'].fillna('tagline',inplace=True)

# %%
movie.isnull().any()
# Out:
# budget                  False
# genres                  False
# homepage                False
# id                      False
# keywords                False
# original_language       False
# original_title          False
# overview                False
# popularity              False
# production_companies    False
# production_countries    False
# release_date            False
# revenue                 False
# runtime                 False
# spoken_languages        False
# status                  False
# tagline                 False
# title                   False
# vote_average            False
# vote_count              False
# dtype: bool

# %% [markdown]
# # task 3

# %%
Budget = movie[movie['budget'] > 220000]
Budget
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # task 4

# %%
r = movie[movie['revenue'] > 961000000]
r
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36   210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %% [markdown]
# # task 5

# %%
br= movie[(movie['budget'] != 0) & (movie['revenue'] != 0)]
br
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # task 6

# %%
top_10_revenue_movies = movie.sort_values(by='revenue', ascending=False).head(10)

top_10_budget_movies = movie.sort_values(by='budget').head(10)

print("Top 10 Movies with the Highest Revenue:")
print(top_10_revenue_movies[['title', 'revenue']])

print("\nTop 10 Movies with the Least Budget:")
print(top_10_budget_movies[['title', 'budget']])
# Out:
# Top 10 Movies with the Highest Revenue:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495
#
# Top 10 Movies with the Least Budget:
#                        title  budget
# 2401          City of Ghosts       0
# 3187                Hamlet 2       0
# 3183       The Ultimate Gift       0
# 3179            Chasing Papi       0
# 3178             The Savages       0
# 3176  Breakin' All the Rules       0
# 3157        Jab Tak Hai Jaan       0
# 3156                 Red Dog       0
# 3154                   Kites       0
# ...

# %% [markdown]
# # task 7

# %%
correlation = movie['popularity'].corr(movie['budget'])

# %%
if correlation > 0:
    interpretation = "There is a positive correlation between movie popularity and budget."
elif correlation < 0:
    interpretation = "There is a negative correlation between movie popularity and budget."
else:
    interpretation = "There is no linear correlation between movie popularity and budget."

print("Correlation Coefficient:", correlation)
print("Interpretation:", interpretation)
# Out:
# Correlation Coefficient: 0.5054139990665322
# Interpretation: There is a positive correlation between movie popularity and budget.

# %% [markdown]
# Interpretation of the correlation coefficient:
#
# If the correlation is close to 1, it suggests a strong positive linear relationship, meaning that as movie budgets increase, popularity tends to increase as well.
#
# If the correlation is close to -1, it suggests a strong negative linear relationship, meaning that as movie budgets increase, popularity tends to decrease.
#
# If the correlation is close to 0, it suggests no significant linear relationship between the two variables.

# %% [markdown]
# The interpretation will give you insights into whether there is a correlation between movie popularity and budget and the direction of that correlation. Keep in mind that correlation does not imply causation, and other factors may also influence movie popularity.

# %% [markdown]
# # task 8

# %%
production_company_counts = movie['production_companies'].value_counts()

print(production_company_counts)
# Out:
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              351
# ...

# %% [markdown]
# # task 9

# %%
production_company_counts = movie['production_companies'].value_counts()

top_25_production_companies = production_company_counts.head(25)
print(top_25_production_companies)
# Out:
# []                                                                                                                  351
# [{"name": "Paramount Pictures", "id": 4}]                                                                            58
# [{"name": "Universal Pictures", "id": 33}]                                                                           45
# [{"name": "New Line Cinema", "id": 12}]                                                                              38
# [{"name": "Columbia Pictures", "id": 5}]                                                                             37
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}]                                                                  32
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                      31
# [{"name": "Warner Bros.", "id": 6194}]                                                                               27
# ...

# %% [markdown]
# # task 10

# %%
movie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
top_500_movies = movie.sort_values(by='revenue', ascending=False).head(500)

# Calculate measures of central tendency for 'Budget', 'Revenue', and 'Runtime'
mean_budget = top_500_movies['budget'].mean()
median_budget = top_500_movies['budget'].median()
mean_revenue = top_500_movies['revenue'].mean()
median_revenue = top_500_movies['revenue'].median()
mean_runtime = top_500_movies['runtime'].mean()
median_runtime = top_500_movies['runtime'].median()

# %%
print("Measures of Central Tendency for Top 500 Movies:")
print(f"Budget: Mean = {mean_budget}, Median = {median_budget}")
print(f"Revenue: Mean = {mean_revenue}, Median = {median_revenue}")
print(f"Runtime: Mean = {mean_runtime}, Median = {median_runtime}")
# Out:
# Measures of Central Tendency for Top 500 Movies:
# Budget: Mean = 102803736.0, Median = 95000000.0
# Revenue: Mean = 458722133.294, Median = 363001569.5
# Runtime: Mean = 118.626, Median = 116.0

# %% [markdown]
# #### Box Plot for Budget

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.boxplot(top_500_movies['budget'])
plt.title('Budget Box Plot')
# Out:
# Text(0.5, 1.0, 'Budget Box Plot')

# %% [markdown]
# #### Box Plot for Revenue

# %%
plt.subplot(1, 3, 2)
plt.boxplot(top_500_movies['revenue'])
plt.title('Revenue Box Plot')
# Out:
# Text(0.5, 1.0, 'Revenue Box Plot')

# %% [markdown]
# #### Box Plot for Runtime

# %%
plt.subplot(1, 3, 3)
plt.boxplot(top_500_movies['runtime'])
plt.title('Runtime Box Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# # task 11

# %%
average_runtime = top_500_movies['runtime'].mean()

# Filter the movies with runtimes above the average
above_average_runtime_movies = top_500_movies[top_500_movies['runtime'] > average_runtime]

# Display the names of the movies along with their runtimes
print("Movies with Above-Average Runtime:")
print(above_average_runtime_movies[['title', 'runtime']])
# Out:
# Movies with Above-Average Runtime:
#                            title runtime
# 0                         Avatar   162.0
# 25                       Titanic   194.0
# 16                  The Avengers   143.0
# 28                Jurassic World   124.0
# 44                     Furious 7   137.0
# ...                          ...     ...
# 1161          The Social Network   120.0
# 912   Interview with the Vampire   123.0
# 521                 The Terminal   128.0
# 397             It's Complicated   121.0
# 1744                  Knocked Up   129.0
#
# [232 rows x 2 columns]
